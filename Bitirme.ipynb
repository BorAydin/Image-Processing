# %%
import librosa
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import IPython.display as ipd

# %%
audio_path = 'C:\\Users\\BorA\\Desktop\\Bitirme\\Tan-Ona Söyle.wav'
x , sr = librosa.load(audio_path)

print(type(x), type(sr))

print (x.shape, sr)
# Out:
# <class 'numpy.ndarray'> <class 'int'>
# (663088,) 22050

# %%
audio_path2 = 'C:\\Users\\BorA\\Desktop\\Bitirme\\Şer-Yanıma Gelmesinler.wav'
y , sr = librosa.load(audio_path2)

print(type(y), type(sr))

print (y.shape, sr)
# Out:
# <class 'numpy.ndarray'> <class 'int'>
# (664146,) 22050

# %%
ipd.Audio(audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(audio_path2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %matplotlib inline
import librosa.display

plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)

n0 = 9000
n1 = 9100
plt.figure(figsize=(14, 5))
plt.plot(x[n0:n1])
plt.grid()



zero_crossings = librosa.zero_crossings(x[n0:n1], pad=False)
print(sum(zero_crossings))
# Out:
# 18

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(y, sr=sr)

n0 = 9000
n1 = 9100
plt.figure(figsize=(14, 5))
plt.plot(y[n0:n1])
plt.grid()


zero_crossings2 = librosa.zero_crossings(y[n0:n1], pad=False)
print(sum(zero_crossings2))
# Out:
# 8

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)
librosa.display.waveplot(y, sr=sr2)

# %%
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
Y = librosa.stft(y)
Ydb = librosa.amplitude_to_db(abs(Y))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Ydb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
mfccs = librosa.feature.mfcc(x, sr=fs)
print (mfccs.shape)


librosa.display.specshow(mfccs, sr=sr, x_axis='time')
# Out:
# (20, 1296)

# %%
mfccs2 = librosa.feature.mfcc(y, sr=fs)
print (mfccs2.shape)


librosa.display.specshow(mfccs2, sr=sr, x_axis='time')
# Out:
# (20, 1298)

# %%
hop_length = 512
chromagram = librosa.feature.chroma_stft(x, sr=sr, hop_length=hop_length)
plt.figure(figsize=(15, 5))
librosa.display.specshow(chromagram, x_axis='time', y_axis='chroma', hop_length=hop_length, cmap='coolwarm')

# %%
hop_length = 512
chromagram = librosa.feature.chroma_stft(y, sr=sr, hop_length=hop_length)
plt.figure(figsize=(15, 5))
librosa.display.specshow(chromagram, x_axis='time', y_axis='chroma', hop_length=hop_length, cmap='coolwarm')
